# %%
import pandas as pd

# %%
datos_covidhospital = pd.read_csv('COVID clinical trials.csv',header =0)
print(datos_covid)
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2        3  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 3        4  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# 4        5  NCT04407585  Testing the Accuracy of a Digital Test to Diag...
# ...    ...          ...                                                ...
# 2590  2591  NCT03261050  Target Engagement of a Novel Dissonance-Based ...
# 2591  2592  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 2592  2593  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 2593  2594  NCT03922334                        Navigating New Motherhood 2
# 2594  2595  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#             Acronym      Status         Study Results  \
# ...

# %%
print(datos_covid['Rank'])
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2590    2591
# 2591    2592
# 2592    2593
# 2593    2594
# 2594    2595
# Name: Rank, Length: 2595, dtype: int64

# %%
print(datos_covid['NCT Number'])
# Out:
# 0       NCT04395924
# 1       NCT04395482
# 2       NCT04367805
# 3       NCT04427332
# 4       NCT04407585
#            ...
# 2590    NCT03261050
# 2591    NCT03823469
# 2592    NCT04429061
# 2593    NCT03922334
# 2594    NCT04180709
# Name: NCT Number, Length: 2595, dtype: object

# %%
print(datos_covid['Title'])
# Out:
# 0              Maternal-foetal Transmission of SARS-Cov-2
# 1       Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2       COVID-19 Infection in Patients With Hepatocell...
# 3          Smell and Taste Disorders in COVID-19 Patients
# 4       Testing the Accuracy of a Digital Test to Diag...
#                               ...
# 2590    Target Engagement of a Novel Dissonance-Based ...
# 2591    Evaluating the Impact of a Culinary Coaching T...
# 2592    Reaching 90 90 90 in Adolescents in Zambia: Us...
# 2593                          Navigating New Motherhood 2
# 2594    CBT to Reduce Insomnia and Improve Social Reco...
# Name: Title, Length: 2595, dtype: object

# %%
print(datos_covid['Acronym'])
# Out:
# 0        TMF-COVID-19
# 1         TAC-COVID19
# 2       COVID19-CHIEF
# 3        COVID-19 ORL
# 4                 NaN
#             ...
# 2590              NaN
# 2591              NaN
# 2592           SKILLZ
# 2593             NNM2
# 2594            CRISP
# Name: Acronym, Length: 2595, dtype: object

# %%
print(datos_covid['Status'])
# Out:
# 0       Recruiting
# 1       Recruiting
# 2       Recruiting
# 3       Recruiting
# 4       Recruiting
#            ...
# 2590    Recruiting
# 2591    Recruiting
# 2592    Recruiting
# 2593    Recruiting
# 2594     Suspended
# Name: Status, Length: 2595, dtype: object

# %%
#Ver las 3 primeras filas
print(datos_covid.ix[0:3])
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1     2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2     3  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 3     4  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
#
#          Acronym      Status         Study Results  \
# 0   TMF-COVID-19  Recruiting  No Results Available
# 1    TAC-COVID19  Recruiting  No Results Available
# 2  COVID19-CHIEF  Recruiting  No Results Available
# 3   COVID-19 ORL  Recruiting  No Results Available
#
#                                           Conditions  \
# 0  Maternal Fetal Infection Transmission|COVID-19...
# 1                                            covid19
# 2                  Hepatocellular Carcinoma|COVID-19
# 3                                            covid19
#
#                                        Interventions  \
# ...

# %%
#acomodar filas 
print(datos_covid.sort_values(by='Gender'))
# Out:
#       Rank   NCT Number                                              Title  \
# 1296  1297  NCT04362332  Chloroquine, Hydroxychloroquine or Only Suppor...
# 1707  1708  NCT04366167  Patient Recovery From Heart Surgery During the...
# 1708  1709  NCT04341493  Hydroxychloroquine vs Nitazoxanide in Patients...
# 1709  1710  NCT04315948  Trial of Treatments for COVID-19 in Hospitaliz...
# 1710  1711  NCT04397848  Mental Health Outcomes in Healthcare Workers D...
# ...    ...          ...                                                ...
# 198    199  NCT04367896  COVID-19 OUTBREAK AND SOLID ORGAN TRANSPLANTAT...
# 278    279  NCT04452682  The Impact of COVID-19 Pandemic on Critical Li...
# 1905  1906  NCT04444531        Clinical Improvement and COVID-19 Pneumonia
# 2367  2368  NCT04382508  Coronavirus Infection in Primary or Secondary ...
# 2461  2462  NCT04363788  Needle Stick Injuries in Emergency Medical Ser...
#
#            Acronym                   Status         Study Results  \
# ...

# %%
print(datos_covid.sort_values(by='Gender',ascending=False))
# Out:
#       Rank   NCT Number                                              Title  \
# 455    456  NCT04446429               Anti-Androgen Treatment for COVID-19
# 2586  2587  NCT04386876  Bioequivalence Study of Lopinavir/Ritonavir 20...
# 469    470  NCT04414904  Determining the Reproductive Health of Men Pos...
# 2572  2573  NCT04400682  Bioequivalence Study of Favipiravir 200 mg Fil...
# 2571  2572  NCT04406194  Bioequivalence Study of Favipiravir 200 mg Fil...
# ...    ...          ...                                                ...
# 198    199  NCT04367896  COVID-19 OUTBREAK AND SOLID ORGAN TRANSPLANTAT...
# 278    279  NCT04452682  The Impact of COVID-19 Pandemic on Critical Li...
# 1905  1906  NCT04444531        Clinical Improvement and COVID-19 Pneumonia
# 2367  2368  NCT04382508  Coronavirus Infection in Primary or Secondary ...
# 2461  2462  NCT04363788  Needle Stick Injuries in Emergency Medical Ser...
#
#           Acronym                   Status         Study Results  \
# ...

# %%
#manejar la columna 11
print(datos_covid[datos_covid.ix[:10]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b6a69e743f4e> in <module>
#       1 #manejar la columna 11
# ----> 2 print(datos_covid[datos_covid.ix[:10]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2965         # Do we have a (boolean) DataFrame?
#    2966         if isinstance(key, DataFrame):
# -> 2967             return self._getitem_frame(key)
#    2968
#    2969         # Do we have a (boolean) 1d indexer?
#
# ...

# %%
print(datos_covid['Gender'])
# Out:
# 0       Female
# 1          All
# 2          All
# 3          All
# 4          All
#          ...
# 2590    Female
# 2591       All
# 2592    Female
# 2593    Female
# 2594       All
# Name: Gender, Length: 2595, dtype: object

# %%
print(datos_covid['Conditions'])
# Out:
# 0       Maternal Fetal Infection Transmission|COVID-19...
# 1                                                 covid19
# 2                       Hepatocellular Carcinoma|COVID-19
# 3                                                 covid19
# 4                                                Covid-19
#                               ...
# 2590                                      Eating Disorder
# 2591                                   Overweight|Obesity
# 2592    HIV Infections|Pregnancy Related|STI|Mental He...
# 2593    Postpartum Health|Breastfeeding|Contraception|...
# 2594                  Psychotic Disorders|Psychosis|Sleep
# Name: Conditions, Length: 2595, dtype: object

# %%
print(datos_covid['Gender'],['Conditions'])
# Out:
# 0       Female
# 1          All
# 2          All
# 3          All
# 4          All
#          ...
# 2590    Female
# 2591       All
# 2592    Female
# 2593    Female
# 2594       All
# Name: Gender, Length: 2595, dtype: object ['Conditions']

# %%
condicion = datos_covid['Conditions']
print(condicion)
# Out:
# 0       Maternal Fetal Infection Transmission|COVID-19...
# 1                                                 covid19
# 2                       Hepatocellular Carcinoma|COVID-19
# 3                                                 covid19
# 4                                                Covid-19
#                               ...
# 2590                                      Eating Disorder
# 2591                                   Overweight|Obesity
# 2592    HIV Infections|Pregnancy Related|STI|Mental He...
# 2593    Postpartum Health|Breastfeeding|Contraception|...
# 2594                  Psychotic Disorders|Psychosis|Sleep
# Name: Conditions, Length: 2595, dtype: object

# %%
#verificar si hay datos nulos
print(datos_covid.isnull())
#true valores perdidos #false valores no perdidos
# Out:
#        Rank  NCT Number  Title  Acronym  Status  Study Results  Conditions  \
# 0     False       False  False    False   False          False       False
# 1     False       False  False    False   False          False       False
# 2     False       False  False    False   False          False       False
# 3     False       False  False    False   False          False       False
# 4     False       False  False     True   False          False       False
# ...     ...         ...    ...      ...     ...            ...         ...
# 2590  False       False  False     True   False          False       False
# 2591  False       False  False     True   False          False       False
# 2592  False       False  False    False   False          False       False
# 2593  False       False  False    False   False          False       False
# 2594  False       False  False    False   False          False       False
#
# ...

# %%
#sumar datos perdidos 
print('Suma datos nulos en el dataFrame: ')
print(datos_covid.isnull().sum())
# Out:
# Suma datos nulos en el dataFrame:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    1378
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               414
# Outcome Measures             22
# Sponsor/Collaborators         0
# Gender                        5
# Age                           0
# Phases                     1127
# Enrollment                   22
# Funded Bys                    0
# Study Type                    0
# Study Designs                23
# Other IDs                     1
# Start Date                   22
# Primary Completion Date      23
# Completion Date              23
# First Posted                  0
# Results First Posted       2594
# Last Update Posted            0
# Locations                   418
# Study Documents            2547
# URL                           0
# dtype: int64

# %%
datos_covid = pd.dropna('Posted')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-df1500c87bee> in <module>
# ----> 1 datos_covid = pd.dropna('Posted')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'dropna'
